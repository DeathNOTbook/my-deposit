# %% [markdown]
# <a href="https://colab.research.google.com/github/DeathNOTbook/my-deposit/blob/master/HEART_DISEASE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('https://raw.githubusercontent.com/DeathNOTbook/my-deposit/master/heart.csv')

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %% [markdown]
# It's a clean, easy to understand set of data. However, the meaning of some of the column headers are not obvious. Here's what they mean,
#
# age: The person's age in years
#
# sex: The person's sex (1 = male, 0 = female)
#
# cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical
#
# angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# chol: The person's cholesterol measurement in mg/dl
#
# fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# thalach: The person's maximum heart rate achieved
#
# exang: Exercise induced angina (1 = yes; 0 = no)
#
# oldpeak: ST depression induced by exercise relative to rest ('ST' relates to positions on the ECG plot. See more here)
#
# slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# ca: The number of major vessels (0-3)
#
# thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 =
# reversable defect)
#
# target: Heart disease (0 = no, 1 = yes)

# %%
values=data.values

# %%
values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
def dict_1(x):
  dic={}
  for i in x:
    if i[13]==1:
      if i[0] in dic:
        dic[i[0]]+=1
      else:
        dic[i[0]]=1
  return dic
def dict_0(x):
    dic={}
    for i in x:
      if i[13]==0:
        if i[0] in dic:
          dic[i[0]]+=1
        else:
          dic[i[0]]=1
    return dic

# %%
def returnSum(dict): 
      
     sum = 0
     for i in dict.values(): 
           sum = sum + i 
       
     return sum

# %%
def prob(p,y):
  s=returnSum(y)
  prob=y[p]/s
  return prob

# %%
c=data['target']
cval=c.values
cval=cval.tolist()
prob_heart=cval.count(1)/len(cval)
prob_heart_0=1-prob_heart

# %%
# given that the person has the heart disease what is the probability that he is of the age 45
val_1=dict_1(values)
val_0=dict_0(values)
ans=(prob(45,val_1)*prob_heart)/(prob(45,val_0)*prob_heart_0+prob(45,val_1)*prob_heart)

# %%
ans
# Out:
# 0.75

# %% [markdown]
# # Odds of a person suffering from a heart disease

# %%
def odds(p):
  return p/(1-p)

# %%
odds_heart=odds(prob_heart)

# %%
print('The odds of a person suffering from a heart disease is:',odds_heart)
# Out:
# The odds of a person suffering from a heart disease is: 1.1956521739130437

# %% [markdown]
# # Cumulative Distribution Function

# %%
# !ls "/content/drive/My Drive"
# Out:
# '013 Data Project - Intro to Election Analysis.mp4'
# 'Colab Notebooks'
# 'financial aid.docx'
# 'financial aid.gdoc'
#  first.py
# 'Getting started.pdf'
# 'house-prices-advanced-regression-techniques (1)'
#  nsfg.py
#  thinkplot.py
#  thinkstats2.py
# 'Untitled spreadsheet.gsheet'

# %%
# !cat '/content/drive/My Drive/nsfg.py'
# !cat '/content/drive/My Drive/thinkplot.py'
# !cat '/content/drive/My Drive/thinkstats2.py'
# !cat '/content/drive/My Drive/first.py'

# %%
import sys
sys.path.append('/content/drive/My Drive')

# %%
import thinkstats2
import thinkplot

# %% [markdown]
# # Relationship between age and heart diseases

# %%
sns.catplot(data=data,x='age',y='target',kind='point',height=8,aspect=2)

# %%
sns.catplot(data=data,x='trestbps',y='target',kind='point',height=8,aspect=2)

# %%
sns.catplot(data=data,x='fbs',y='target',kind='bar',height=4,aspect=2)

# %%
x=[int(x) for x in range(0,100)]

# %%
for i in data:
  print(i)
# Out:
# age
# sex
# cp
# trestbps
# chol
# fbs
# restecg
# thalach
# exang
# oldpeak
# slope
# ca
# thal
# target
